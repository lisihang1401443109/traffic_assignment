# %%
import runner

# %%
# runner.compare_xfc_result_vary_proning()
runner.compare_xfc_exe_time_vary_proning(pronings=[0, 10, 5, 1], out_alias='xfc_exe_time_5.json')
# Out:
# 74 nodes, 258 links,
# 5476 OD pairs
# selected 7 nodes as xfc using method='degree'
# Experiment(self.input_path='/home/sihang/workspace/traffic_proj/inputs/EMA/'
# self.output_path='/home/sihang/workspace/traffic_proj/outputs/EMA/'
# self.algorithm='dijkstra'
# self.method='automatic'
# self.alpha=0.15
# self.threashold=0.001
# self.maxIter=100
# self.xfc=True
# )
# 74 nodes, 258 links,
# 5476 OD pairs
# selected 7 nodes as xfc using method='degree'
# Experiment(self.input_path='/home/sihang/workspace/traffic_proj/inputs/EMA/'
# self.output_path='/home/sihang/workspace/traffic_proj/outputs/EMA/'
# self.algorithm='dijkstra'
# self.method='automatic'
# self.alpha=0.15
# self.threashold=0.001
# self.maxIter=100
# self.xfc=True
# )
# 74 nodes, 258 links,
# 5476 OD pairs
# selected 7 nodes as xfc using method='degree'
# Experiment(self.input_path='/home/sihang/workspace/traffic_proj/inputs/EMA/'
# self.output_path='/home/sihang/workspace/traffic_proj/outputs/EMA/'
# ...
