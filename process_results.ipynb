# %%
# %cd ./outputs
# Out:
# /home/sihang/workspace/traffic_proj/outputs

# %%
import json
import os
from typing import Any
import re

# %%
def tokenize(dat: str) -> dict[str, Any]:
    '''
    a input might look like this:
        total_time: 1324528.8856405413 units
        converged within 4 iterations
        alpha=0.15
    this function is supposed to tokenize it into:
    {
        total_time: 1324528.8856405413,
        converged: True,
        iteration: 4,
        alpha=0.15
    }
    '''

    result = {}

    # Extract total_time using regular expression
    total_time_match = re.search(r'total_time:\s+(\d+\.\d+)\s+units', dat)
    if total_time_match:
        result['total_time'] = float(total_time_match.group(1))

    # Extract iteration using regular expression
    iteration_match = re.search(r'converged within (\d+) iterations', dat)
    if iteration_match:
        result['iteration'] = int(iteration_match.group(1))

    # Extract alpha using regular expression
    alpha_match = re.search(r'alpha=(\d+\.\d+)', dat)
    if alpha_match:
        result['alpha'] = float(alpha_match.group(1))

    # Set converged to True
    result['converged'] = not re.search(r'not converged', dat)

    return result

# %%
results = dict()
for path in os.listdir():
    if os.path.isfile(path):
        continue
    _dat_list = [item for item in os.listdir(path) if '.dat' in item]
    dat_list = [open(path + '/' + item, 'r').read() for item in _dat_list]
    dat_list = [tokenize(item) for item in dat_list]
    for dat, file in zip(dat_list, _dat_list):
        # dat['precision'] = float(file.split('_')[-1][:-4])
        dat['precision'] = 0.001
    results[path] = dat_list
results
# Out:
# {'EMA': [{'total_time': 28453.295561750245,
#    'iteration': 24,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 29164.529615772615,
#    'iteration': 101,
#    'alpha': 0.3,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 29459.95794683791,
#    'iteration': 101,
#    'alpha': 0.4,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 28788.94111597809,
#    'iteration': 10,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 114548.5021274435,
#    'iteration': 101,
#    'alpha': 0.5,
#    'converged': False,
#    'precision': 0.001}],
#  'Braess': [{'total_time': 537.4619726637222,
#    'iteration': 101,
#    'alpha': 0.2,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 548.8028577072876,
#    'iteration': 101,
#    'alpha': 0.3,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 557.1448946035538,
#    'iteration': 101,
#    'alpha': 0.4,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 544.2810938930413,
#    'iteration': 101,
#    'alpha': 0.1,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 529.6289063139843,
#    'iteration': 10,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Barcelona': [{'total_time': 1303592.6928432237,
#    'iteration': 11,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1316602.6931082706,
#    'iteration': 18,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1330099.6612928554,
#    'iteration': 8,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1303966.0037383516,
#    'iteration': 15,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1392156.1317296992,
#    'iteration': 20,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Winnipeg': [{'total_time': 949391.2643552425,
#    'iteration': 6,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 937284.9868667747,
#    'iteration': 47,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1023496.1830656148,
#    'iteration': 91,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 932912.7469110005,
#    'iteration': 13,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1163650.3277857502,
#    'iteration': 54,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Anaheim': [{'total_time': 1326397.4091595185,
#    'iteration': 8,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1324861.4016110965,
#    'iteration': 6,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1332048.8139667234,
#    'iteration': 38,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1327260.65458546,
#    'iteration': 12,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1343047.314112128,
#    'iteration': 13,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'ChicagoSketch': [{'total_time': 18496374.737660047,
#    'iteration': 11,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 18520588.764031887,
#    'iteration': 93,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 19779359.921726666,
#    'iteration': 101,
#    'alpha': 0.4,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 18473299.191361133,
#    'iteration': 20,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 20747444.029233344,
#    'iteration': 68,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'SiouxFalls': [{'total_time': 7824176.217147182,
#    'iteration': 20,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 9790470.295156376,
#    'iteration': 11,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 19213116.324450225,
#    'iteration': 101,
#    'alpha': 0.4,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 7783795.50910212,
#    'iteration': 27,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 52535751.77920768,
#    'iteration': 101,
#    'alpha': 0.5,
#    'converged': False,
#    'precision': 0.001}]}

# %%
json.dump(results, open('alpha_results.json', 'w'))
