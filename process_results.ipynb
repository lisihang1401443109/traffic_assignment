# %%
# %cd ./outputs
# Out:
# /home/sihang/workspace/traffic_proj/outputs

# %%
import json
import os
from typing import Any
import re

# %%
def tokenize(dat: str) -> dict[str, Any]:
    '''
    a input might look like this:
        total_time: 1324528.8856405413 units
        converged within 4 iterations
        alpha=0.15
    this function is supposed to tokenize it into:
    {
        total_time: 1324528.8856405413,
        converged: True,
        iteration: 4,
        alpha=0.15
    }
    '''

    result = {}

    # Extract total_time using regular expression
    total_time_match = re.search(r'total_time:\s+(\d+\.\d+)\s+units', dat)
    if total_time_match:
        result['total_time'] = float(total_time_match.group(1))

    # Extract iteration using regular expression
    iteration_match = re.search(r'converged within (\d+) iterations', dat)
    if iteration_match:
        result['iteration'] = int(iteration_match.group(1))

    # Extract alpha using regular expression
    alpha_match = re.search(r'alpha=(\d+\.\d+)', dat)
    if alpha_match:
        result['alpha'] = float(alpha_match.group(1))

    # Set converged to True
    result['converged'] = not re.search(r'not converged', dat)

    return result

# %%
results = dict()
for path in os.listdir():
    if os.path.isfile(path):
        continue
    _dat_list = [item for item in os.listdir(path) if '.dat' in item]
    dat_list = [open(path + '/' + item, 'r').read() for item in _dat_list]
    dat_list = [tokenize(item) for item in dat_list]
    for dat, file in zip(dat_list, _dat_list):
        # dat['precision'] = float(file.split('_')[-1][:-4])
        dat['precision'] = 0.001
    results[path] = dat_list
results
# Out:
# {'EMA': [{'total_time': 28678.31196209787,
#    'iteration': 9,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 28678.31196209787,
#    'iteration': 9,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 28678.31196209787,
#    'iteration': 9,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 28678.31196209787,
#    'iteration': 9,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 28678.31196209787,
#    'iteration': 9,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Braess': [{'total_time': 551.2224000798001,
#    'iteration': 101,
#    'alpha': 0.2,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 551.2224000798001,
#    'iteration': 101,
#    'alpha': 0.3,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 551.2224000798001,
#    'iteration': 101,
#    'alpha': 0.4,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 551.2224000798001,
#    'iteration': 101,
#    'alpha': 0.1,
#    'converged': False,
#    'precision': 0.001},
#   {'total_time': 551.2224000798001,
#    'iteration': 101,
#    'alpha': 0.5,
#    'converged': False,
#    'precision': 0.001}],
#  'Barcelona': [{'total_time': 1305904.0377473154,
#    'iteration': 8,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1305904.0377473154,
#    'iteration': 8,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1305904.0377473154,
#    'iteration': 8,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1305904.0377473154,
#    'iteration': 8,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1305904.0377473154,
#    'iteration': 8,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Winnipeg': [{'total_time': 930149.1295963333,
#    'iteration': 12,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 930149.1295963333,
#    'iteration': 12,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 930149.1295963333,
#    'iteration': 12,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 930149.1295963333,
#    'iteration': 12,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 930149.1295963333,
#    'iteration': 12,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'Anaheim': [{'total_time': 1323568.6510970236,
#    'iteration': 7,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1323568.6510970236,
#    'iteration': 7,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1323568.6510970236,
#    'iteration': 7,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1323568.6510970236,
#    'iteration': 7,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 1323568.6510970236,
#    'iteration': 7,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'ChicagoSketch': [{'total_time': 18506202.19459631,
#    'iteration': 11,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 18506202.19459631,
#    'iteration': 11,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 18506202.19459631,
#    'iteration': 11,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 18506202.19459631,
#    'iteration': 11,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 18506202.19459631,
#    'iteration': 11,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}],
#  'SiouxFalls': [{'total_time': 21308209.54711252,
#    'iteration': 4,
#    'alpha': 0.2,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 21308209.54711252,
#    'iteration': 4,
#    'alpha': 0.3,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 21308209.54711252,
#    'iteration': 4,
#    'alpha': 0.4,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 21308209.54711252,
#    'iteration': 4,
#    'alpha': 0.1,
#    'converged': True,
#    'precision': 0.001},
#   {'total_time': 21308209.54711252,
#    'iteration': 4,
#    'alpha': 0.5,
#    'converged': True,
#    'precision': 0.001}]}

# %%
json.dump(results, open('alpha_results.json', 'w'))
